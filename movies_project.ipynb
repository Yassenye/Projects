# %%
import pandas as  pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib
plt.rcParams['figure.figsize'] = (12, 8)
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
#read in the data 
df = pd.read_csv("D:/Data_analyst/project/python/movies.csv")

# %%
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# missing data 
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}-{}%'.format(col,  pct_missing))
# Out:
# name-0.0%
# rating-0.010041731872717789%
# genre-0.0%
# year-0.0%
# released-0.0002608242044861763%
# score-0.0003912363067292645%
# votes-0.0003912363067292645%
# director-0.0%
# writer-0.0003912363067292645%
# star-0.00013041210224308815%
# country-0.0003912363067292645%
# budget-0.2831246739697444%
# gross-0.02464788732394366%
# company-0.002217005738132499%
# runtime-0.0005216484089723526%

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# datatypes
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'].fillna(0, inplace=True)
df['gross'].fillna(0, inplace=True)
df['runtime'].fillna(0, inplace=True)
df['votes'].fillna(0, inplace=True)


df['budget'] = df['budget'] .astype('int64')
df['runtime'] = df['runtime'] .astype('int64')
df['gross'] = df['gross'] .astype('int64')
df['votes'] = df['gross'] .astype('int64')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8816\3737605094.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['budget'].fillna(0, inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_8816\3737605094.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.dtypes['budget']
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   46998772  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8   58853106   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  538375067   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   83453539     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   39846344     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# year columns
df['Yearcorect'] = df['released'].astype(str).str[4:4]

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   46998772  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8   58853106   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  538375067   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   83453539     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   39846344     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df['yearCorect'] = df['released'].astype(str).str[4:4]

# %%
df.head()
# Out:
#                                             name  rating  genre  year  \
# 5445                                      Avatar       5      0  2009
# 7445                           Avengers: Endgame       5      0  2019
# 3045                                     Titanic       5      6  1997
# 6663  Star Wars: Episode VII - The Force Awakens       5      0  2015
# 7244                      Avengers: Infinity War       5      0  2018
#
#       released  score       votes  director  writer  star  country     budget  \
# 5445       696    7.8  2847246203      1155    1778  2334       55  237000000
# 7445       183    8.4  2797501328       162     743  2241       55  356000000
# 3045       704    7.8  2201647264      1155    1778  1595       55  200000000
# 6663       698    7.8  2069521700      1125    2550   524       55  245000000
# 7244       192    8.4  2048359754       162     743  2241       55  321000000
#
#            gross  company  runtime
# 5445  2847246203     2253      162
# ...

# %%
df.dtypes
# Out:
# name           object
# rating         object
# genre          object
# year            int64
# released       object
# score         float64
# votes           int64
# director       object
# writer         object
# star           object
# country        object
# budget          int64
# gross           int64
# company        object
# runtime         int64
# Yearcorect     object
# yearCorect     object
# dtype: object

# %%
#extract the year str
df['release_year'] = df['released'].str.extract(r'(\d{4})')

# %%
df = df.sort_values(by=['gross'],inplace=False,ascending=False)

# %%
#show whole rows
pd.set_option('display.max_rows' , None)

# %%
#drope an duplicates
df['company'].drop_duplicates().head(15)
# Out:
# 5445    2253
# 7445    1606
# 6663    1540
# 7480    2316
# 6653    2281
# 7494    2315
# 5845    2319
# 7072    1592
# 6688    1313
# 4245    1713
# 7458     731
# 5878    1812
# 6059    1637
# 7488    1856
# 6905    1008
# Name: company, dtype: int16

# %%
#budget high correlation
#

# %%
#scatter plot with bugdet vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross earnings')
plt.xlabel('Gross earnings')
plt.ylabel('Budget for film')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score       votes       director  \
# 5445  December 18, 2009 (United States)    7.8  2847246203  James Cameron
# 7445     April 26, 2019 (United States)    8.4  2797501328  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  2201647264  James Cameron
# 6663  December 18, 2015 (United States)    7.8  2069521700    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4  2048359754  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
#plot budget vs gross using  seaborn

sns.regplot(x='budget', y='gross' , data=df,scatter_kws={"color":"red"},line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.drop(columns=['Yearcorect', 'yearCorect', 'release_year'], inplace=True)

# %%
df.dtypes
df.dtypes
# Out:
# name        category
# rating          int8
# genre           int8
# year           int64
# released       int16
# score        float64
# votes          int64
# director       int16
# writer         int16
# star           int16
# country         int8
# budget         int64
# gross          int64
# company        int16
# runtime        int64
# dtype: object

# %%
#df.corr(method = 'pearson')
#peason,kindall,spearman

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr(method='pearson')
print(correlation_matrix)
# Out:
#             rating     genre      year  released     score     votes  \
# rating    1.000000  0.072423  0.008779  0.016613 -0.001314 -0.095450
# genre     0.072423  1.000000 -0.081261  0.029822  0.027965 -0.234297
# year      0.008779 -0.081261  1.000000 -0.000695  0.097995  0.261900
# released  0.016613  0.029822 -0.000695  1.000000  0.042788  0.000519
# score    -0.001314  0.027965  0.097995  0.042788  1.000000  0.186392
# votes    -0.095450 -0.234297  0.261900  0.000519  0.186392  1.000000
# director  0.019483 -0.015258 -0.020795 -0.001478  0.009559 -0.014916
# writer   -0.005921  0.006567 -0.008656 -0.002404  0.019416 -0.022997
# star      0.013405 -0.005477 -0.027242  0.015777 -0.001609 -0.001129
# country   0.081244 -0.037615 -0.070938 -0.020427 -0.133348  0.095325
# budget   -0.081939 -0.334021  0.309212  0.009145  0.055665  0.750157
# gross    -0.095450 -0.234297  0.261900  0.000519  0.186392  1.000000
# company  -0.032943 -0.071067 -0.010431 -0.010474  0.001030  0.156745
# ...

# %%
numeric_df.dropna(inplace=True)  # or numeric_df.fillna(0, inplace=True)

# %%
#High correlation between budget and gross
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movies Features')
plt.ylabel('Movies Features')


plt.show()

# %%
#look at company 
df.head()
# Out:
#                                             name  rating  genre  year  \
# 5445                                      Avatar       5      0  2009
# 7445                           Avengers: Endgame       5      0  2019
# 3045                                     Titanic       5      6  1997
# 6663  Star Wars: Episode VII - The Force Awakens       5      0  2015
# 7244                      Avengers: Infinity War       5      0  2018
#
#       released  score       votes  director  writer  star  country     budget  \
# 5445       696    7.8  2847246203      1155    1778  2334       55  237000000
# 7445       183    8.4  2797501328       162     743  2241       55  356000000
# 3045       704    7.8  2201647264      1155    1778  1595       55  200000000
# 6663       698    7.8  2069521700      1125    2550   524       55  245000000
# 7244       192    8.4  2048359754       162     743  2241       55  321000000
#
#            gross  company  runtime
# 5445  2847246203     2253      162
# ...

# %%
df_numerized = df
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes


df_numerized.head()
# Out:
#                                             name  rating  genre  year  \
# 5445                                      Avatar       5      0  2009
# 7445                           Avengers: Endgame       5      0  2019
# 3045                                     Titanic       5      6  1997
# 6663  Star Wars: Episode VII - The Force Awakens       5      0  2015
# 7244                      Avengers: Infinity War       5      0  2018
#
#       released  score       votes  director  writer  star  country     budget  \
# 5445       696    7.8  2847246203      1155    1778  2334       55  237000000
# 7445       183    8.4  2797501328       162     743  2241       55  356000000
# 3045       704    7.8  2201647264      1155    1778  1595       55  200000000
# 6663       698    7.8  2069521700      1125    2550   524       55  245000000
# 7244       192    8.4  2048359754       162     743  2241       55  321000000
#
#            gross  company  runtime
# 5445  2847246203     2253      162
# ...

# %%
df.head()
# Out:
#                                             name  rating  genre  year  \
# 5445                                      Avatar       5      0  2009
# 7445                           Avengers: Endgame       5      0  2019
# 3045                                     Titanic       5      6  1997
# 6663  Star Wars: Episode VII - The Force Awakens       5      0  2015
# 7244                      Avengers: Infinity War       5      0  2018
#
#       released  score       votes  director  writer  star  country     budget  \
# 5445       696    7.8  2847246203      1155    1778  2334       55  237000000
# 7445       183    8.4  2797501328       162     743  2241       55  356000000
# 3045       704    7.8  2201647264      1155    1778  1595       55  200000000
# 6663       698    7.8  2069521700      1125    2550   524       55  245000000
# 7244       192    8.4  2048359754       162     743  2241       55  321000000
#
#            gross  company  runtime
# 5445  2847246203     2253      162
# ...

# %%
#
numeric_df = df_numerized.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movies Features')
plt.ylabel('Movies Features')


plt.show()


#df_numerized.head()

# %%
# Select only numeric columns
numeric_df = df_numerized.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()



print(correlation_matrix)
# Out:
#             rating     genre      year  released     score     votes  \
# rating    1.000000  0.072423  0.008779  0.016613 -0.001314 -0.095450
# genre     0.072423  1.000000 -0.081261  0.029822  0.027965 -0.234297
# year      0.008779 -0.081261  1.000000 -0.000695  0.097995  0.261900
# released  0.016613  0.029822 -0.000695  1.000000  0.042788  0.000519
# score    -0.001314  0.027965  0.097995  0.042788  1.000000  0.186392
# votes    -0.095450 -0.234297  0.261900  0.000519  0.186392  1.000000
# director  0.019483 -0.015258 -0.020795 -0.001478  0.009559 -0.014916
# writer   -0.005921  0.006567 -0.008656 -0.002404  0.019416 -0.022997
# star      0.013405 -0.005477 -0.027242  0.015777 -0.001609 -0.001129
# country   0.081244 -0.037615 -0.070938 -0.020427 -0.133348  0.095325
# budget   -0.081939 -0.334021  0.309212  0.009145  0.055665  0.750157
# gross    -0.095450 -0.234297  0.261900  0.000519  0.186392  1.000000
# company  -0.032943 -0.071067 -0.010431 -0.010474  0.001030  0.156745
# ...

# %%
numeric_df = df_numerized.select_dtypes(include=[np.number])
correlation_mat = numeric_df.corr()

corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# rating    rating      1.000000
#           genre       0.072423
#           year        0.008779
#           released    0.016613
#           score      -0.001314
#           votes      -0.095450
#           director    0.019483
#           writer     -0.005921
#           star        0.013405
#           country     0.081244
#           budget     -0.081939
#           gross      -0.095450
#           company    -0.032943
#           runtime     0.064133
# genre     rating      0.072423
#           genre       1.000000
#           year       -0.081261
#           released    0.029822
#           score       0.027965
#           votes      -0.234297
#           director   -0.015258
#           writer      0.006567
#           star       -0.005477
#           country    -0.037615
#           budget     -0.334021
#           gross      -0.234297
#           company    -0.071067
#           runtime    -0.052914
# year      rating      0.008779
#           genre      -0.081261
# ...

# %%
sorted_apirs = corr_pairs.sort_values()
sorted_apirs
# Out:
# budget    genre      -0.334021
# genre     budget     -0.334021
# gross     genre      -0.234297
# genre     votes      -0.234297
#           gross      -0.234297
# votes     genre      -0.234297
# score     country    -0.133348
# country   score      -0.133348
# votes     rating     -0.095450
# gross     rating     -0.095450
# rating    votes      -0.095450
#           gross      -0.095450
# budget    rating     -0.081939
# rating    budget     -0.081939
# genre     year       -0.081261
# year      genre      -0.081261
# country   runtime    -0.073319
# runtime   country    -0.073319
# genre     company    -0.071067
# company   genre      -0.071067
# year      country    -0.070938
# country   year       -0.070938
# runtime   genre      -0.052914
# genre     runtime    -0.052914
#           country    -0.037615
# country   genre      -0.037615
# company   rating     -0.032943
# rating    company    -0.032943
# star      year       -0.027242
# year      star       -0.027242
# ...

# %%
high_correlation = sorted_apirs[(sorted_apirs)>0.5]

high_correlation
# Out:
# budget    gross       0.750157
# votes     budget      0.750157
# gross     budget      0.750157
# budget    votes       0.750157
# rating    rating      1.000000
# gross     gross       1.000000
#           votes       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# votes     gross       1.000000
#           votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
#votes and budget have the highest correlation to gross earnings
